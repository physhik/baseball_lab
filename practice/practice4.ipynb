# %%
git clone https://github.com/physhik/baseball_lab.git
# Out:
# Cloning into 'baseball_lab'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 57 (delta 17), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (57/57), done.

# %%
cd baseball_lab/src
# Out:
# /content/baseball_lab/src

# %%
from opc import *

# %%
main(2015)
# Out:
# Park name is changed for  Turner Field (Cumberland, Georgia)
# The determinant of 30x30 matrice must be near zero,  -0.004432736317999547
# Ideally sum of the factors is 30, and here is  30.0
#                       RUNS     HR      H  ...     BB RUNS x OPC RUNS x mOPC
# TEAMS(PARK)                               ...
# Arizona              1.062  0.856  1.047  ...  1.025   1.059810    1.039894
# Atlanta              0.937  0.720  0.915  ...  1.114   0.938972    0.923950
# Baltimore            1.228  1.415  1.121  ...  0.936   1.218738    1.232243
# Boston               1.191  0.971  1.103  ...  0.920   1.183465    1.193289
# Chicago Cubs         0.950  1.276  0.934  ...  1.029   0.951586    0.944155
# Chicago White Sox    0.904  1.113  0.953  ...  1.234   0.906902    0.924827
# Cincinnati           1.115  1.137  1.075  ...  1.101   1.110742    1.092020
# Cleveland            1.261  0.986  1.169  ...  1.115   1.250124    1.260165
# ...
